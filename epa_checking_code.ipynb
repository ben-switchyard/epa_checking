# %% [markdown]
# # Maverick Truck Club - EPA Checking code
#
# Run the code to check the fueleconomy.gov Web Services for 2022 Fords!

# %%
import pip
import smtplib
import datetime
pip.main(['install', 'sinbad'])

from sinbad import *
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting sinbad
#   Downloading sinbad-0.5b9.tar.gz (22 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jsonpath_rw>=1.4.0 (from sinbad)
#   Downloading jsonpath-rw-1.4.0.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting satori-rtm-sdk>=1.4.0 (from sinbad)
#   Downloading satori_rtm_sdk-1.5.0-py2.py3-none-any.whl.metadata (997 bytes)
# Collecting xmltodict>=0.11.0 (from sinbad)
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Collecting appdirs>=1.4.3 (from sinbad)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting ply (from jsonpath_rw>=1.4.0->sinbad)
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from jsonpath_rw>=1.4.0->sinbad) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from jsonpath_rw>=1.4.0->sinbad) (1.17.0)
# Collecting cbor2 (from satori-rtm-sdk>=1.4.0->sinbad)
#   Downloading cbor2-6.1.3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from satori-rtm-sdk>=1.4.0->sinbad) (2026.6.17)
# Collecting enum34 (from satori-rtm-sdk>=1.4.0->sinbad)
#   Downloading enum34-1.1.10-py3-none-any.whl.metadata (1.6 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading satori_rtm_sdk-1.5.0-py2.py3-none-any.whl (49 kB)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Downloading cbor2-6.1.3-cp312-cp312-manylinux_2_28_x86_64.whl (468 kB)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Downloading enum34-1.1.10-py3-none-any.whl (11 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Building wheels for collected packages: sinbad, jsonpath_rw
#   Building wheel for sinbad (setup.py): started
#   Building wheel for sinbad (setup.py): finished with status 'done'
#   Created wheel for sinbad: filename=sinbad-0.5b9-py3-none-any.whl size=26924 sha256=b8e0628219f9da5c59ab21dc0f25b66a2f7bb88da9e654542be6f01718c959b9
#   Stored in directory: /root/.cache/pip/wheels/68/a8/01/4c97defd0fd58a505202f1c709583200e401cd591a2ab3fe4e
#   Building wheel for jsonpath_rw (setup.py): started
#   Building wheel for jsonpath_rw (setup.py): finished with status 'done'
#   Created wheel for jsonpath_rw: filename=jsonpath_rw-1.4.0-py3-none-any.whl size=15127 sha256=5ea4b4deb01481838ad2ccdd54da7de3e02aa8f674cf94c731d3a162c0f48e52
#   Stored in directory: /root/.cache/pip/wheels/e5/8d/50/ee73263c97069bd6040ff40633d444fefaac7beff73abe81a7
# Successfully built sinbad jsonpath_rw
# Installing collected packages: ply, enum34, appdirs, xmltodict, jsonpath_rw, cbor2, satori-rtm-sdk, sinbad
# Successfully installed appdirs-1.4.4 cbor2-6.1.3 enum34-1.1.10 jsonpath_rw-1.4.0 ply-3.11 satori-rtm-sdk-1.5.0 sinbad-0.5b9 xmltodict-1.0.4
# Welcome to Sinbad (version 0.5b9).
# For help and documentation, visit http://cs.berry.edu/sinbad/

# %%
ds = DataSource.connect("https://www.fueleconomy.gov/ws/rest/vehicle/menu/model", format="xml")
ds.set_param("year", "2024")
ds.set_param("make", "Ford")
ds.load()
makes = ds.fetch('text')

# %%
#Print all 2022 Fords
print(makes)
# Out:
# ['Bronco 4WD', 'Bronco Badlands 4WD', 'Bronco Black Diamond 4WD', 'Bronco Raptor 4WD', 'Bronco Sasquatch 4WD', 'Bronco Sport 4WD', 'Edge AWD', 'Escape AWD', 'Escape AWD HEV', 'Escape FWD', 'Escape FWD HEV', 'Expedition 2WD', 'Expedition 4WD', 'Expedition Timberline AWD', 'Explorer AWD', 'Explorer FFV AWD', 'Explorer RWD', 'Explorer Timberline AWD', 'F-150 Lightning 4WD', 'F-150 Lightning 4WD Extended Range', 'F-150 Lightning Platinum 4WD', 'F-150 Lightning PRO 4WD Extended Range', 'F150 Pickup 2WD', 'F150 Pickup 4WD', 'F150 Pickup 4WD HEV', 'F150 Pickup Tremor 4WD', 'F150 RAPTOR 4WD', 'F150 RAPTOR R 4WD', 'Maverick AWD', 'Maverick FWD', 'Maverick HEV FWD', 'Maverick Tremor AWD', 'Mustang', 'Mustang Dark Horse', 'Mustang Mach-E AWD', 'Mustang Mach-E AWD Extended', 'Mustang Mach-E GT', 'Mustang Mach-E Rally', 'Mustang Mach-E RWD', 'Mustang Mach-E RWD Extended', 'Mustang Performance Package', 'Ranger 2WD', 'Ranger 4WD', 'Ranger RAPTOR 4WD']

# %%
# is there a record for hybrid?
[x for x in makes if 'Maverick' in x and 'HEV' in x]
valid = [x for x in makes if 'Maverick' in x and 'HEV' in x]
if not valid:
  valid = [x for x in makes if 'Maverick' in x and 'FWD' in x]

# valid = 'Maverick AWD' if [x for x in makes if 'ybrid' in x]  else [x for x in makes if 'ybrid' in x]

print(valid)
# Out:
# ['Maverick HEV FWD']

# %%
available = 'Not checked'
if [x for x in makes if 'Maverick' in x and 'HEV' in x]:
  available = True
else:
  available = False

print(available)

makelist = '\n'.join(makes)
# Out:
# True

# %%
ds = DataSource.connect("http://www.fueleconomy.gov/ws/rest/vehicle/menu/options", format="xml")
ds.set_param("year", "2022")
ds.set_param("make", "Ford").set_param("model", valid[0])
ds.load()

num = ds.fetch('value')
print(num)
if isinstance(num, list):
  num=num[0]

ds = DataSource.connect_load("http://www.fueleconomy.gov/ws/rest/vehicle/"+num, format="xml")
mpgdata = (ds.fetch("make", "model", "trany", "year", "city08", "highway08","comb08") )
mpgdataprint = ('make: '+mpgdata['make'],'model: '+mpgdata['model']+'\nyear: '+mpgdata['year']+'\nCity MPG: '+mpgdata['city08']+'\nHighway MPG: '+mpgdata['highway08']+'\nCombo MPG: '+mpgdata['comb08'])

mpgdatalist = '\n'.join(mpgdataprint)
print(mpgdatalist)
# Out:
# 45110
# make: Ford
# model: Maverick HEV FWD
# year: 2022
# City MPG: 42
# Highway MPG: 33
# Combo MPG: 37

# %%
personalemail = 'test@gmail.com'
passwordkey = 'ENTERPASS'
toAddress = [personalemail]

# %%
if available == True:
    conn = smtplib.SMTP('smtp.gmail.com', 587) # smtp address and port
    conn.ehlo() # call this to start the connection
    conn.starttls() # starts tls encryption. When we send our password it will be encrypted.
    conn.login(personalemail, passwordkey)
    conn.sendmail(personalemail, toAddress, 'Subject: EPA Alert!\n\nAttention!\n\nYour MPG is available today!\n\nhttps://www.fueleconomy.gov/feg/PowerSearch.do?action=noform&path=1&year1=2022&year2=2022&make=Ford&baseModel=Maverick&srchtyp=ymm&pageno=1&rowLimit=50\n\n\nAvailable:'+makelist+'\n\nFirst Record\n\n'+mpgdatalist+'+\n\nGO GET IT!')
    conn.quit()
    print('Sent notificaton e-mails for the following recipients:\n')
    for i in range(len(toAddress)):
        print(toAddress[i])
    print('')
else:
    print('The Maverick Hybrid EPA is not available.')
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# /tmp/ipykernel_2445/3106870025.py in <cell line: 0>()
#       3     conn.ehlo() # call this to start the connection
#       4     conn.starttls() # starts tls encryption. When we send our password it will be encrypted.
# ----> 5     conn.login(personalemail, passwordkey)
#       6     conn.sendmail(personalemail, toAddress, 'Subject: EPA Alert!\n\nAttention!\n\nYour MPG is available today!\n\nhttps://www.fueleconomy.gov/feg/PowerSearch.do?action=noform&path=1&year1=2022&year2=2022&make=Ford&baseModel=Maverick&srchtyp=ymm&pageno=1&rowLimit=50\n\n\nAvailable:'+makelist+'\n\nFirst Record\n\n'+mpgdatalist+'+\n\nGO GET IT!')
#       7     conn.quit()
#
# /usr/lib/python3.12/smtplib.py in login(self, user, password, initial_response_ok)
#     748
#     749         # We could not login successfully.  Return result of last attempt.
# --> 750         raise last_exception
#     751
#     752     def starttls(self, *, context=None):
#
# /usr/lib/python3.12/smtplib.py in login(self, user, password, initial_response_ok)
#     737             method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738             try:
# --> 739                 (code, resp) = self.auth(
#     740                     authmethod, getattr(self, method_name),
#     741                     initial_response_ok=initial_response_ok)
#
# /usr/lib/python3.12/smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     660         if code in (235, 503):
#     661             return (code, resp)
# --> 662         raise SMTPAuthenticationError(code, resp)
#     663
#     664     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 71dfb90a1353d-5c2c62b6450sm4209587e0c.6 - gsmtp')

# %%
#import datetime
# record = []
#record.append(datetime.datetime.now().strftime("%a, %d %B %Y %H:%M:%S"))
#print('\n'.join(record))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2445/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
with open('/content/drive/MyDrive/EPA.txt', 'a') as writefile:
    writefile.write(datetime.datetime.now().strftime("%a, %d %B %Y %H:%M:%S")+'\n')

# %%
with open('/content/drive/MyDrive/EPA.txt', 'r') as testwritefile:
    print(testwritefile.read())
